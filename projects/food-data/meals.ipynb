# %%
molly_meals = {
    
    'Breakfast': {
        'cheese': 0.5,
        'eggs': 1.3,
        'spinach': 0.5,
    },

    'Lunch': {
        'cottage cheese': 2.5,
        'spinach': 0.5,
        'avocado': 1.6,
        'red pepper': 1,
        'lettuce': 1.5,
        'nuts and seed mix': .5,        
        'flaxseed oil': .2,
    },
    
    'Snack': {
        'nuts and seed mix': 0.5,
        'nature yoghurt': 1,
        'cheese': 0.5,
        'half-and-half cream': 0.3,
    },

    'Supper': {
        'eggs': 1.3,
        'vegetables': 2,
    }
}

fab_meals = {
    
#     'Breakfast': {
#         'cauliflower': 1,
#         'cheese': 1.5,
#         'eggs': 2.5,
#         'spinach': 0.5,
#     },

    'Lunch': {
        'eggs': 2,
        'cheese': 0.5,
        'spinach': 0.5,
        'leek': 1,
        'cream': 0.5,
        'mushrooms': 1,
        'avocado': 1.6,
        'lettuce': 1.5,
        'nuts and seed mix': .5,        
        'olive oil': .2,
    },
    
    'Snack': {
        'nuts and seed mix': 0.5,
        'nature yoghurt': 1,
        'cocoa': 0.03,
        'cinnamon': 0.01,
        'coconut flakes': 0.0,
#         'whey protein': 0.2 need to add this to database
    },

    'Supper': {
        'avocado': 0.8,
        'chicken': 2,
        'vegetables': 2,
    }
}
    

pa_meals = {

    'Zmittag': {
        'oats': 0.5,
        'milk': 1.5,        
        'nature yoghurt': 0.8,
        'mocca yoghurt': 1.5,
        'nuts': 0.4,
        'fig': 0.2
    },
    
    'Znacht': {
        'rice': 1.5,
        'dark chocolate': .15,
        'cheese': 0.6,
        'eggs': 0.6,
        'beer': 5
    }, 

}

# %store pa_meals
# %store fa_meals
# Out:
# Stored 'pa_meals' (dict)
# Stored 'fa_meals' (dict)
