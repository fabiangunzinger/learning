# %%
import pandas as pd
import matplotlib.pyplot as plt

# import engarde.decorators as ed

pd.set_option('display.max_colwidth', None)
# %config InlineBackend.figure_format = 'retina'


def read(file):
    df = ((pd.read_excel(file, skiprows=2, usecols=columns))
          .rename(columns, axis=1)
          .pipe(str_to_numeric, ['fat', 'carbs', 'fiber', 'protein'])
          .pipe(str_to_lower, ['name', 'category'])
          .pipe(strip_strings, ['name'])
          .assign(net_carbs = lambda x: x.carbs - x.fiber)
          .dropna(how='any'))
    return df


columns = {
    'Name': 'name',
    'Kategorie': 'category',
    'Bezugseinheit': 'units',
    'Energie, Kalorien': 'calories',
    'Fett, total (g)': 'fat',
    'Kohlenhydrate, verfügbar (g)': 'carbs',
    'Nahrungsfasern (g)': 'fiber',
    'Protein (g)': 'protein'
}


def strip_strings(df, columns):
    """
    Remove leading and trailing whitespace from strings.
    """
    df = df.copy()
    def strip(col):
        return col.str.strip()
    
    df[columns] = df[columns].apply(strip)
    return df
    
    
def str_to_numeric(df, columns):
    """
    Convert string columns to numeric.
    """
    df = df.copy()
    def converter(col):
        return pd.to_numeric(col, errors='coerce')

    df[columns] = df[columns].apply(converter)
    return df


def str_to_lower(df, columns):
    """
    Convert string columns to lower-case.
    """
    df = df.copy()
    def converter(col):
        return col.str.lower()
    
    df[columns] = df[columns].apply(converter)
    return df


def find_item(data, item):
    return data[data.name.str.contains(item)]


def make_myfoods(data, foods):
    df = data.copy()
    df = df.loc[data.name.isin(foods)]
    df = df.rename(columns={'name': 'ingredient'})
    df['ingredient'] = df['ingredient'].map(foods)
    
    return df


my_foods = {
    'avocado, roh': 'avocado',
    'blattsalat (durchschnitt), roh': 'lettuce',
    'bier, lager': 'beer',
    'blumenkohl, gedämpft (ohne zugabe von salz)': 'cauliflower',
    'champignon, roh': 'mushrooms',    
    'feige, getrocknet': 'fig',
    'fleisch (durchschnitt exkl. innereien), roh': 'meat',
    'forelle, ganz, gekocht (ohne zusatz von fett und salz)': 'trout',
    'gemüse (durchschnitt), roh': 'vegetables',
    'hart- und halbhartkäse, vollfett (durchschnitt)': 'cheese',
    'haferflocken': 'oats',
    'halbentrahmte milch 1.5% fett, uht': 'milk',
    'hühnerei, ganz, festgekocht': 'eggs',
    'joghurt, mokka': 'mocca yoghurt',
    'joghurt, nature': 'nature yoghurt',
    'kakaopulver': 'cocoa powder', 
    'kartoffel, geschält, roh': 'potatoes',
    'kochbutter': 'butter',
    'kokosfett': 'coconut fat',
    'kokosnuss, getrocknet (kokosrapseln, kokosflocken)': 'coconut flakes',
    'mandel': 'almond',
    'olivenöl': 'olive oil',
    'peperoni, rot, roh': 'red pepper',
    'poulet, schenkel, mit haut, gebraten (ohne zusatz von fett und salz)': 'chicken leg',
    'poulet, brust, schnitzel oder geschnetzeltes, gebraten (ohne zusatz von fett und salz)': 'chicken breast',
    'reis poliert, gekocht in salzwasser (unjodiert)': 'rice',
    'samen, kerne, nüsse (durchschnitt), ungesalzen': 'nuts and seed mix',
    'schokolade, dunkel (bitter)': 'dark chocolate',
    'schwein, hals, steak, gebraten (ohne zusatz von fett und salz)': 'pork steak',
    'spinat, roh': 'spinach', 
    'tofu': 'tofu',
    'vollrahm, uht': 'cream'
}


foods = read('Schweizer-Nährwertdatenbank-V6.1.xlsx')
myfoods = make_myfoods(foods, my_foods).set_index('ingredient')

# %store foods myfoods
# Out:
# Stored 'foods' (DataFrame)
# Stored 'myfoods' (DataFrame)

# %%
myfoods
# Out:
#                                                                                                                                                                                           category  \
# ingredient
# avocado                                                                                                                                            gemüse/gemüse frisch;nüsse, samen und ölfrüchte
# beer                                                                                                                                                                  alkoholhaltige getränke/bier
# lettuce                                                                                                                                                                       gemüse/gemüse frisch
# cauliflower                                                                                                                                                gemüse/gemüse gekocht (inkl. konserven)
# mushrooms                                                                                                                                                                             gemüse/pilze
# fig                                                                                                                                                                     früchte/früchte getrocknet
# meat               fleisch und innereien/kalb;fleisch und innereien/geflügel;fleisch und innereien/lamm, schaf;fleisch und innereien/rind;fleisch und innereien/schwein;fleisch und innereien/wild
# trout                                                                                                                                                                       fisch/süsswasserfische
# vegetables                                                                                                                                                                    gemüse/gemüse frisch
# oats                                                                                                                               brote, flocken und frühstückscerealien/flocken, kleie und keime
# milk                                                                                                                                                                 milch und milchprodukte/milch
# cheese                                                                                                                                                            milch und milchprodukte/hartkäse
# eggs                                                                                                                                                                                          eier
# mocca yoghurt                                                                                                                                       milch und milchprodukte/joghurt und sauermilch
# nature yoghurt                                                                                                                                      milch und milchprodukte/joghurt und sauermilch
# cocoa powder                                                                                                      süssigkeiten/schokolade und kakaoerzeugnisse;alkoholfreie getränke/kakaogetränke
# potatoes                                                                                                                                 getreideprodukte, hülsenfrüchte und kartoffeln/kartoffeln
# butter                                                                                                                                 fette und öle/fette;milch und milchprodukte/rahm und butter
# coconut fat                                                                                                                                                                    fette und öle/fette
# coconut flakes                                                                                                                                                          nüsse, samen und ölfrüchte
# almond                                                                                                                                                                  nüsse, samen und ölfrüchte
# olive oil                                                                                                                                                                        fette und öle/öle
# red pepper                                                                                                                                                                    gemüse/gemüse frisch
# chicken breast                                                                                                                                                      fleisch und innereien/geflügel
# chicken leg                                                                                                                                                         fleisch und innereien/geflügel
# rice                                                                                                                                           getreideprodukte, hülsenfrüchte und kartoffeln/reis
# nuts and seed mix                                                                                                                                                       nüsse, samen und ölfrüchte
# dark chocolate                                                                                                                                        süssigkeiten/schokolade und kakaoerzeugnisse
# pork steak                                                                                                                                                           fleisch und innereien/schwein
# spinach                                                                                                                                                                       gemüse/gemüse frisch
# tofu                                                                                                                                                                         fleischersatzprodukte
# cream                                                                                                                                   fette und öle/rahm;milch und milchprodukte/rahm und butter
#
#                                       units  calories   fat  carbs  fiber  \
# ingredient
# avocado            pro 100g essbarer Anteil       144  14.2    0.8    3.0
# beer                             pro 100 ml        42   0.0    3.1    0.0
# lettuce            pro 100g essbarer Anteil        18   0.3    1.4    1.9
# cauliflower        pro 100g essbarer Anteil        28   0.3    2.4    2.5
# mushrooms          pro 100g essbarer Anteil        25   0.3    1.1    1.9
# fig                pro 100g essbarer Anteil       273   1.2   56.8   11.0
# meat               pro 100g essbarer Anteil       145   6.6    0.0    0.0
# trout              pro 100g essbarer Anteil       159   8.8    0.0    0.0
# vegetables         pro 100g essbarer Anteil        26   0.3    3.7    2.0
# oats               pro 100g essbarer Anteil       381   7.5   59.5   10.5
# milk                             pro 100 ml        46   1.5    4.8    0.0
# cheese             pro 100g essbarer Anteil       397  32.1    0.0    0.0
# eggs               pro 100g essbarer Anteil       157  11.4    0.3    0.0
# mocca yoghurt      pro 100g essbarer Anteil        99   3.1   14.1    0.0
# nature yoghurt     pro 100g essbarer Anteil        66   3.6    4.5    0.0
# cocoa powder       pro 100g essbarer Anteil       419  24.5   10.8   32.7
# potatoes           pro 100g essbarer Anteil        76   0.1   15.6    2.1
# butter             pro 100g essbarer Anteil       745  82.2    0.7    0.0
# coconut fat        pro 100g essbarer Anteil       894  99.0    0.0    0.0
# coconut flakes     pro 100g essbarer Anteil       667  63.3    6.4   20.0
# almond             pro 100g essbarer Anteil       593  49.9    4.0   13.0
# olive oil                        pro 100 ml       810  90.0    0.0    0.0
# red pepper         pro 100g essbarer Anteil        32   0.4    5.2    2.0
# chicken breast     pro 100g essbarer Anteil       131   1.5    0.4    0.0
# chicken leg        pro 100g essbarer Anteil       218  13.6    0.0    0.0
# rice               pro 100g essbarer Anteil       117   0.3   25.9    0.3
# nuts and seed mix  pro 100g essbarer Anteil       608  50.6   11.2    9.5
# dark chocolate     pro 100g essbarer Anteil       537  31.8   53.4    7.0
# pork steak         pro 100g essbarer Anteil       298  20.7    0.0    0.0
# spinach            pro 100g essbarer Anteil        23   0.4    0.8    2.6
# tofu               pro 100g essbarer Anteil        81   4.8    0.7    1.2
# cream              pro 100g essbarer Anteil       335  34.9    3.1    0.0
#
#                    protein  net_carbs
# ingredient
# avocado                1.8       -2.2
# beer                   0.5        3.1
# lettuce                1.6       -0.5
# cauliflower            2.5       -0.1
# mushrooms              3.7       -0.8
# fig                    3.2       45.8
# meat                  21.4        0.0
# trout                 20.1        0.0
# vegetables             1.3        1.7
# oats                  13.5       49.0
# milk                   3.2        4.8
# cheese                26.6        0.0
# eggs                  13.2        0.3
# mocca yoghurt          3.7       14.1
# nature yoghurt         3.9        4.5
# cocoa powder          22.5      -21.9
# potatoes               2.0       13.5
# butter                 0.5        0.7
# coconut fat            0.8        0.0
# coconut flakes         8.1      -13.6
# almond                25.5       -9.0
# olive oil              0.0        0.0
# red pepper             0.9        3.2
# chicken breast        28.9        0.4
# chicken leg           23.9        0.0
# rice                   2.5       25.6
# nuts and seed mix     22.2        1.7
# dark chocolate         5.7       46.4
# pork steak            27.8        0.0
# spinach                2.7       -1.8
# tofu                   8.1       -0.5
# cream                  2.0        3.1

# %% [markdown]
# Find items

# %%
find_item(foods, 'ei')
# Out:
#                                               name  \
# 2                       älplermagronen, zubereitet
# 11         apfelkuchen, gebacken (mit blätterteig)
# 12          apfelkuchen, gebacken (mit kuchenteig)
# 17                               apfelwein, 4 vol%
# 18                             apfelwein, 6.2 vol%
# ...                                            ...
# 1004                                 zucker, weiss
# 1008  zwetschgenkuchen, gebacken (mit blätterteig)
# 1009   zwetschgenkuchen, gebacken (mit kuchenteig)
# 1015     zwiebelkuchen, gebacken (mit blätterteig)
# 1016      zwiebelkuchen, gebacken (mit kuchenteig)
#
#                                                               category  \
# 2                           gerichte/sonstige salzige/rezente gerichte
# 11    süssigkeiten/kuchen, torten und cake;gerichte/kuchen und gratins
# 12    süssigkeiten/kuchen, torten und cake;gerichte/kuchen und gratins
# 17                                        alkoholhaltige getränke/wein
# 18                                        alkoholhaltige getränke/wein
# ...                                                                ...
# 1004                                süssigkeiten/zucker und süssstoffe
# 1008  süssigkeiten/kuchen, torten und cake;gerichte/kuchen und gratins
# 1009  süssigkeiten/kuchen, torten und cake;gerichte/kuchen und gratins
# 1015                                       gerichte/kuchen und gratins
# 1016                                       gerichte/kuchen und gratins
#
#                          units  calories   fat  carbs  fiber  protein  \
# 2     pro 100g essbarer Anteil       183   9.0   18.6    1.7      6.0
# 11    pro 100g essbarer Anteil       141   7.0   16.5    1.7      2.3
# 12    pro 100g essbarer Anteil       144   6.1   18.7    1.8      2.7
# 17                  pro 100 ml        32   0.0    2.5    0.0      0.0
# 18                  pro 100 ml        64   0.0    7.3    0.0      0.0
# ...                        ...       ...   ...    ...    ...      ...
# 1004  pro 100g essbarer Anteil       400   0.0  100.0    0.0      0.0
# 1008  pro 100g essbarer Anteil       134   6.8   14.6    1.8      2.5
# 1009  pro 100g essbarer Anteil       136   6.0   16.8    1.9      2.9
# 1015  pro 100g essbarer Anteil       178  11.5   13.2    1.5      4.7
# 1016  pro 100g essbarer Anteil       181  10.7   15.3    1.6      5.0
#
#       net_carbs
# 2          16.9
# 11         14.8
# 12         16.9
# 17          2.5
# 18          7.3
# ...         ...
# 1004      100.0
# 1008       12.8
# 1009       14.9
# 1015       11.7
# 1016       13.7
#
# [329 rows x 9 columns]
